# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import PoissonRegressor
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import cross_val_score
from sklearn import set_config
set_config(display='diagram')
from lazypredict.Supervised import LazyRegressor

# %%
data = pd.read_csv("data/train.csv")
data.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL        65.00     8450   Pave   NaN      Reg
# 1   2          20       RL        80.00     9600   Pave   NaN      Reg
# 2   3          60       RL        68.00    11250   Pave   NaN      IR1
# 3   4          70       RL        60.00     9550   Pave   NaN      IR1
# 4   5          60       RL        84.00    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
X = data.drop(columns = ["Id", "SalePrice"])
y = data.SalePrice

# %%
X.replace(['Po', 'Fa', 'TA', 'Gd', 'Ex'], [1, 2, 3, 4, 5], inplace=True)
X.replace(['No', 'Mn','Av'], [1, 2, 3], inplace=True)
X[['LotFrontage', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 'BsmtExposure', 'PoolQC', 'FireplaceQu', 'MasVnrArea']] = X[['LotFrontage', 'BsmtQual', 'BsmtCond', 'GarageQual', 'GarageCond', 'BsmtExposure', 'PoolQC', 'FireplaceQu', 'MasVnrArea']].fillna(value=0)

# %%
null = {}
drop = []
for i in range(0,X.shape[1]):
    if 0 < X.iloc[:,i].isna().sum() <= X.shape[0]*(0.3):
        null[X.columns[i]] = X.iloc[:,i].isna().sum()
    elif X.iloc[:,i].isna().sum() > X.shape[0]*(0.3):# If the null percentage is greater than 30% we will drop that columns. 
        drop.append(X.columns[i])
X.drop(columns = drop, inplace=True)

# %%
drop
# Out:
# ['Alley', 'Fence', 'MiscFeature']

# %%
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
X['GarageYrBlt'] = imputer.fit_transform(X[['GarageYrBlt']])

# %%
X_cat = X.select_dtypes(include = "object")
X_num = X.select_dtypes(include = ["int64", "float64"])

# %%
scaler = MinMaxScaler()
scaled = scaler.fit_transform(X_num)
df_scaled = pd.DataFrame(scaled)

# %%
X_cat = X_cat.fillna(value="None")

# %%
encoder = OneHotEncoder(sparse = False)
encoded = encoder.fit_transform(X_cat)
df_encoded = pd.DataFrame(encoded)

# %%
df_concat = pd.concat([df_scaled, df_encoded], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(df_concat, y, test_size=0.30, random_state=42)

# %%
reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
# 100%|██████████| 42/42 [00:17<00:00,  2.43it/s]

# %%
models
# Out:
#                                                               Adjusted R-Squared  \
# Model
# PoissonRegressor                                                            0.85
# GammaRegressor                                                              0.81
# GradientBoostingRegressor                                                   0.80
# LGBMRegressor                                                               0.77
# HistGradientBoostingRegressor                                               0.77
# RandomForestRegressor                                                       0.77
# XGBRegressor                                                                0.75
# BayesianRidge                                                               0.74
# RidgeCV                                                                     0.74
# BaggingRegressor                                                            0.74
# Lasso                                                                       0.74
# Ridge                                                                       0.74
# HuberRegressor                                                              0.73
# ElasticNet                                                                  0.72
# PassiveAggressiveRegressor                                                  0.71
# ExtraTreesRegressor                                                         0.71
# LassoCV                                                                     0.70
# OrthogonalMatchingPursuit                                                   0.70
# OrthogonalMatchingPursuitCV                                                 0.69
# GeneralizedLinearRegressor                                                  0.69
# TweedieRegressor                                                            0.69
# AdaBoostRegressor                                                           0.64
# LassoLarsCV                                                                 0.61
# LassoLars                                                                   0.61
# LassoLarsIC                                                                 0.61
# KNeighborsRegressor                                                         0.51
# DecisionTreeRegressor                                                       0.50
# LarsCV                                                                      0.49
# ExtraTreeRegressor                                                          0.43
# ElasticNetCV                                                               -0.50
# DummyRegressor                                                             -1.29
# NuSVR                                                                      -1.31
# SVR                                                                        -1.36
# KernelRidge                                                               -10.12
# MLPRegressor                                                              -11.05
# LinearSVR                                                                 -11.79
# GaussianProcessRegressor                                                  -11.86
# SGDRegressor                                                              -63.57
# RANSACRegressor                                       -5175504607203066642432.00
# TransformedTargetRegressor                          -190749772046613130248192.00
# LinearRegression                                    -190749772046613130248192.00
# Lars                          -7046107600242162950334310863172027283093503641...
#
#                                                                        R-Squared  \
# Model
# PoissonRegressor                                                            0.93
# GammaRegressor                                                              0.92
# GradientBoostingRegressor                                                   0.91
# LGBMRegressor                                                               0.90
# HistGradientBoostingRegressor                                               0.90
# RandomForestRegressor                                                       0.90
# XGBRegressor                                                                0.89
# BayesianRidge                                                               0.89
# RidgeCV                                                                     0.89
# BaggingRegressor                                                            0.89
# Lasso                                                                       0.89
# Ridge                                                                       0.89
# HuberRegressor                                                              0.88
# ElasticNet                                                                  0.88
# PassiveAggressiveRegressor                                                  0.87
# ExtraTreesRegressor                                                         0.87
# LassoCV                                                                     0.87
# OrthogonalMatchingPursuit                                                   0.87
# OrthogonalMatchingPursuitCV                                                 0.87
# GeneralizedLinearRegressor                                                  0.86
# TweedieRegressor                                                            0.86
# AdaBoostRegressor                                                           0.84
# LassoLarsCV                                                                 0.83
# LassoLars                                                                   0.83
# LassoLarsIC                                                                 0.83
# KNeighborsRegressor                                                         0.78
# DecisionTreeRegressor                                                       0.78
# LarsCV                                                                      0.78
# ExtraTreeRegressor                                                          0.75
# ElasticNetCV                                                                0.35
# DummyRegressor                                                             -0.00
# NuSVR                                                                      -0.01
# SVR                                                                        -0.03
# KernelRidge                                                                -3.86
# MLPRegressor                                                               -4.27
# LinearSVR                                                                  -4.59
# GaussianProcessRegressor                                                   -4.62
# SGDRegressor                                                              -27.22
# RANSACRegressor                                       -2262062654406832422912.00
# TransformedTargetRegressor                           -83371181832730218332160.00
# LinearRegression                                     -83371181832730218332160.00
# Lars                          -3079648859602409517669881179192515201549893372...
#
#                                                                             RMSE  \
# Model
# PoissonRegressor                                                        21497.98
# GammaRegressor                                                          24234.45
# GradientBoostingRegressor                                               24864.92
# LGBMRegressor                                                           26450.91
# HistGradientBoostingRegressor                                           26571.15
# RandomForestRegressor                                                   26600.90
# XGBRegressor                                                            27806.68
# BayesianRidge                                                           27966.18
# RidgeCV                                                                 28044.19
# BaggingRegressor                                                        28096.34
# Lasso                                                                   28167.70
# Ridge                                                                   28172.82
# HuberRegressor                                                          28679.09
# ElasticNet                                                              29268.98
# PassiveAggressiveRegressor                                              29544.17
# ExtraTreesRegressor                                                     29559.42
# LassoCV                                                                 30095.53
# OrthogonalMatchingPursuit                                               30300.84
# OrthogonalMatchingPursuitCV                                             30556.80
# GeneralizedLinearRegressor                                              30692.72
# TweedieRegressor                                                        30692.72
# AdaBoostRegressor                                                       32981.02
# LassoLarsCV                                                             34551.87
# LassoLars                                                               34551.87
# LassoLarsIC                                                             34636.86
# KNeighborsRegressor                                                     38779.48
# DecisionTreeRegressor                                                   38902.39
# LarsCV                                                                  39470.27
# ExtraTreeRegressor                                                      41535.28
# ElasticNetCV                                                            67545.82
# DummyRegressor                                                          83545.18
# NuSVR                                                                   83854.91
# SVR                                                                     84849.83
# KernelRidge                                                            184142.07
# MLPRegressor                                                           191692.22
# LinearSVR                                                              197519.56
# GaussianProcessRegressor                                               198046.85
# SGDRegressor                                                           443760.59
# RANSACRegressor                                              3973019669668163.50
# TransformedTargetRegressor                                  24119948668873884.00
# LinearRegression                                            24119948668873884.00
# Lars                          46357392606870611634473643959999895522470368283...
#
#                                Time Taken
# Model
# PoissonRegressor                     0.05
# GammaRegressor                       0.03
# GradientBoostingRegressor            0.85
# LGBMRegressor                        0.20
# HistGradientBoostingRegressor        3.51
# RandomForestRegressor                2.44
# XGBRegressor                         0.38
# BayesianRidge                        0.10
# RidgeCV                              0.06
# BaggingRegressor                     0.27
# Lasso                                0.18
# Ridge                                0.02
# HuberRegressor                       0.18
# ElasticNet                           0.08
# PassiveAggressiveRegressor           0.48
# ExtraTreesRegressor                  2.17
# LassoCV                              0.33
# OrthogonalMatchingPursuit            0.03
# OrthogonalMatchingPursuitCV          0.08
# GeneralizedLinearRegressor           0.03
# TweedieRegressor                     0.03
# AdaBoostRegressor                    0.44
# LassoLarsCV                          0.10
# LassoLars                            0.04
# LassoLarsIC                          0.03
# KNeighborsRegressor                  0.21
# DecisionTreeRegressor                0.08
# LarsCV                               0.51
# ExtraTreeRegressor                   0.06
# ElasticNetCV                         0.20
# DummyRegressor                       0.03
# NuSVR                                0.30
# SVR                                  0.46
# KernelRidge                          0.06
# MLPRegressor                         1.43
# LinearSVR                            0.03
# GaussianProcessRegressor             0.52
# SGDRegressor                         0.03
# RANSACRegressor                      1.03
# TransformedTargetRegressor           0.04
# LinearRegression                     0.04
# Lars                                 0.13

# %%
poisson_reg = PoissonRegressor(alpha = 2, max_iter = 2500)

# %%
poisson_reg.fit(X_train, y_train)
# Out:
# PoissonRegressor(alpha=2, max_iter=2500)

# %%
poisson_reg.score(X_train, y_train)
# Out:
# 0.9490391712344209

# %%
poisson_reg.score(X_test, y_test)
# Out:
# 0.9296673419175238

# %%
def rmse_cv(model):
    rmse= np.sqrt(-cross_val_score(model, X_test, y_test, scoring="neg_mean_squared_error", cv = 5))
    return(rmse)

# %%
rmse_cv(poisson_reg).min()
# Out:
# 28126.700421932583
